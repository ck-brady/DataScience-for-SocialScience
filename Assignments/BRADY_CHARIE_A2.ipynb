# %% [markdown]
# # <div align="center"> SPECIAL TOPICS III </div>
# ## <div align="center"> Data Science for Social Scientists  </div>
# ### <div align="center"> ECO 4199 </div>
# # <div align="center"> Assignment 2 </div>
# ## <div align="center" style="color:red">Charie Brady</div>
# ## <div align="center" style="color:red">300043672</div>

# %% [markdown]
# # INSTRUCTIONS
# This Jupyter Notebook contains __3 Parts__ for a total of __10 points__. Some, __but not all__, of the resources needed to answer these questions are coming from what we have seen during the first 5 lectures. You may otherwise need to look for the answers using the internet. I highly recommend looking at the answers in [Stackoverflow](https://stackoverflow.com/) - these are usually the first answers referenced by Google. And of course you have my office hours!
#
# Also, I sometimes left the output of the correction to make clear what I expect you to do.
#
# <br>
# Once you filled out all the tasks, you should restart your Kernel and use the <i>run all cells</i> command. Then you can save the Jupyter Notebook as <strong>LASTNAME_FIRSTNAME_A2.ipynb</strong> and post it in the assignment tab in Brightspace.
# <br>
#
# The deadline for the submitting is <strong>November 2, 2021 at 11:59pm</strong>.
#
#
# <br>
# In the spirit of open source softwares you are allowed to work collaboratively <strong> BUT </strong>:
#
# - I shall receive one notebook per student (No notebook = zero).
# - Coding should reflect personal work (Identical notebooks = zero). This includes but is not limited to:
#     - your own name and student number (obviously)
#     - your own comments on code
#     - you own names for variables, functions, dictionaries, dataframes and so on.
#
# Have fun!

# %% [markdown]
# ## Part 1 - Simple linear regression model
#
# - Remember the Titanic dataset you used for Assignment 1?
# - Now that you performed some data cleaning and visualization let's try to use it for statistical analysis
# - Import the relevant packages (this was done for you)
# - Save the path to the Titanic dataset on your laptop (or Drive)
#     - It means I should be able to change it to my own path and then run your entire notebook!
#     - Failure to respect this will make you lose points
# - Read the data into df, create a new variable named nameLength and show the head of the dataframe
#
#
# - Using the pacakge [Statsmodels](https://www.statsmodels.org/stable/example_formulas.html) and OLS regression produce 4 regressions by regressing `Fare` on:
#     1. `nameLength`
#     2. `Age`
#     3. `Parents/Children Aboard`, you may want to rename it first
#     4. `Pclass`, careful you will need to specify this is a [categorical variable](https://www.statsmodels.org/stable/example_formulas.html#:~:text=is%20correctly%20specified.-,Categorical%20variables,%C2%B6,-Looking%20at%20the)
#
#
# - For each regression add below a `Markdown` cell in which you will:
#     1. Interpret the coefficient values
#     2. Interpret their significance
#
#
# - Finally, show that $\hat{\beta}_1$ estimated using the OLS method can also be obtained by computing the covariance of Y and X over the variance of X for your first model: `Fare ~ nameLength`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
titanicPath=" "

# %%
df=pd.read_csv('/'.join([titanicPath,'titanic.csv']))
df['nameLength'] = df['Name'].str.len()
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare  \
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500
#
#    nameLength
# 0          22
# 1          50
# 2          21
# 3          43
# 4          23

# %% [markdown]
# ### Model 1

# %%
mod = 
print(mod.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                       0.030
# Model:                            OLS   Adj. R-squared:                  0.029
# Method:                 Least Squares   F-statistic:                     27.33
# Date:                Mon, 18 Oct 2021   Prob (F-statistic):           2.14e-07
# Time:                        11:39:18   Log-Likelihood:                -4710.7
# No. Observations:                 887   AIC:                             9425.
# Df Residuals:                     885   BIC:                             9435.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.7054      4.986      1.546      0.123      -2.080      17.491
# nameLength     0.9715      0.186      5.228      0.000       0.607       1.336
# ==============================================================================
# Omnibus:                      924.317   Durbin-Watson:                   2.047
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            50564.051
# Skew:                           4.945   Prob(JB):                         0.00
# Kurtosis:                      38.642   Cond. No.                         81.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Interpretation:

# %% [markdown]
# ####  $\hat{\beta}_1 = \frac{cov(Y,X)}{var(X)}$

# %%
Syx= df[['Fare','nameLength']].cov().iloc[0,1] # covariance
Vx= #variance
beta_1= # ratio
print(f"The value for the slope obtained using OLS: {mod.params['nameLength']} is the same as the one obtained from computing the covariance of X and Y over the variance of X: {beta_1}" )
# Out:
# The value for the slope obtained using OLS: 0.9714705801490848 is the same as the one obtained from computing the covariance of X and Y over the variance of X: 0.971470580149083

# %% [markdown]
# ### Model 2

# %%
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     11.31
# Date:                Mon, 18 Oct 2021   Prob (F-statistic):           0.000804
# Time:                        11:39:18   Log-Likelihood:                -4718.6
# No. Observations:                 887   AIC:                             9441.
# Df Residuals:                     885   BIC:                             9451.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     20.6354      3.848      5.363      0.000      13.084      28.187
# Age            0.3960      0.118      3.363      0.001       0.165       0.627
# ==============================================================================
# Omnibus:                      900.823   Durbin-Watson:                   2.018
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            44382.719
# Skew:                           4.777   Prob(JB):                         0.00
# Kurtosis:                      36.310   Cond. No.                         75.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Interpretation:

# %% [markdown]
# ### Model 3

# %%
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                       0.046
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     43.09
# Date:                Mon, 18 Oct 2021   Prob (F-statistic):           8.90e-11
# Time:                        11:39:18   Log-Likelihood:                -4703.1
# No. Observations:                 887   AIC:                             9410.
# Df Residuals:                     885   BIC:                             9420.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     27.2134      1.808     15.051      0.000      23.665      30.762
# fam_aboard    13.2842      2.024      6.564      0.000       9.312      17.256
# ==============================================================================
# Omnibus:                      914.901   Durbin-Watson:                   2.071
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            49877.473
# Skew:                           4.859   Prob(JB):                         0.00
# Kurtosis:                      38.428   Cond. No.                         1.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Interpretation:

# %% [markdown]
# ### Model 4

# %%
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                       0.353
# Model:                            OLS   Adj. R-squared:                  0.351
# Method:                 Least Squares   F-statistic:                     240.7
# Date:                Mon, 18 Oct 2021   Prob (F-statistic):           3.62e-84
# Time:                        11:39:18   Log-Likelihood:                -4531.4
# No. Observations:                 887   AIC:                             9069.
# Df Residuals:                     884   BIC:                             9083.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept         84.1547      2.729     30.841      0.000      78.799      89.510
# C(Pclass)[T.2]   -63.4925      4.023    -15.782      0.000     -71.389     -55.596
# C(Pclass)[T.3]   -70.4470      3.278    -21.488      0.000     -76.881     -64.013
# ==============================================================================
# Omnibus:                      970.299   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            83955.075
# Skew:                           5.163   Prob(JB):                         0.00
# Kurtosis:                      49.529   Cond. No.                         4.55
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Part 2 - Multiple linear regression model
#
#
# - Using the pacakge [Statsmodels](https://www.statsmodels.org/stable/example_formulas.html) and OLS regression, regress `Fare` on:
#     1. `nameLength + Age + Parents/Children Aboard `
#     2. `nameLength + Age + nameLength*Age`
#     3. `log(nameLength) + Age + Parents/Children Aboard`, you will need to use `np.log()`
#     4. `Age + Age^2`, you will need to create Age squared
#     5. `Age + Age^2 + Age^3`, you will need to create Age cubed
#
#
# - For each regression add below a cell in which you will:
#     1. Interpret the R-squared, `Markdown`
#     2. Compute the mean squarred error of in-sample prediction using your model, you will first need to use the [predict method](https://www.statsmodels.org/stable/examples/notebooks/generated/predict.html#:~:text=In-sample-,prediction,-%C2%B6) and then use the [mean_squarred_error function](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html) from Scikit-Learn
#
#
# - Finally, discuss which model seems to best predict `Fare`. Mention the criteria you used

# %% [markdown]
# ### Model 1

# %%
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                       0.081
# Model:                            OLS   Adj. R-squared:                  0.078
# Method:                 Least Squares   F-statistic:                     26.08
# Date:                Mon, 18 Oct 2021   Prob (F-statistic):           3.61e-16
# Time:                        11:39:18   Log-Likelihood:                -4686.5
# No. Observations:                 887   AIC:                             9381.
# Df Residuals:                     883   BIC:                             9400.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -3.1342      5.736     -0.546      0.585     -14.391       8.123
# nameLength     0.5953      0.189      3.147      0.002       0.224       0.967
# Age            0.5178      0.117      4.432      0.000       0.288       0.747
# fam_aboard    13.3152      2.113      6.301      0.000       9.168      17.463
# ==============================================================================
# Omnibus:                      931.576   Durbin-Watson:                   2.080
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            56019.283
# Skew:                           4.967   Prob(JB):                         0.00
# Kurtosis:                      40.644   Cond. No.                         146.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Interpretation

# %%
Y_pred=mod.predict(df[['FILL THE RIGHT COLUMNS']])
Y_true= df['Fare'].values
mse= mean_squared_error(Y_true, Y_pred)
print(f"The in-sample MSE of this model is: {mse}")
# Out:
# The in-sample MSE of this model is: 2273.9738274243136

# %% [markdown]
# ### Model 2

# %%
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.037
# Method:                 Least Squares   F-statistic:                     12.40
# Date:                Mon, 18 Oct 2021   Prob (F-statistic):           6.01e-08
# Time:                        11:39:18   Log-Likelihood:                -4705.9
# No. Observations:                 887   AIC:                             9420.
# Df Residuals:                     883   BIC:                             9439.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          5.0477     13.759      0.367      0.714     -21.957      32.053
# nameLength         0.6636      0.523      1.268      0.205      -0.364       1.691
# Age                0.1415      0.407      0.348      0.728      -0.657       0.940
# nameLength:Age     0.0083      0.015      0.550      0.583      -0.021       0.038
# ==============================================================================
# Omnibus:                      926.705   Durbin-Watson:                   2.043
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            51222.075
# Skew:                           4.962   Prob(JB):                         0.00
# Kurtosis:                      38.881   Cond. No.                     7.56e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.56e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Interpretation

# %%
# Out:
# The in-sample MSE of this model is: 2375.399671188585

# %% [markdown]
# ### Model 3

# %%
df['ln_nameLength']=
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                       0.080
# Model:                            OLS   Adj. R-squared:                  0.077
# Method:                 Least Squares   F-statistic:                     25.74
# Date:                Mon, 18 Oct 2021   Prob (F-statistic):           5.75e-16
# Time:                        11:39:18   Log-Likelihood:                -4687.0
# No. Observations:                 887   AIC:                             9382.
# Df Residuals:                     883   BIC:                             9401.
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept       -38.8502     16.759     -2.318      0.021     -71.743      -5.957
# ln_nameLength    15.8781      5.307      2.992      0.003       5.461      26.295
# Age               0.5275      0.117      4.523      0.000       0.299       0.756
# fam_aboard       13.3916      2.116      6.329      0.000       9.239      17.544
# ==============================================================================
# Omnibus:                      930.971   Durbin-Watson:                   2.082
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            55817.738
# Skew:                           4.963   Prob(JB):                         0.00
# Kurtosis:                      40.573   Cond. No.                         359.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Interpretation

# %%
# Out:
# The in-sample MSE of this model is: 2276.399287958661

# %% [markdown]
# ### Model 4

# %%
df['Age_2']=np.power(df['Age'],2)
df['Age_3']=np.power()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     6.034
# Date:                Mon, 18 Oct 2021   Prob (F-statistic):            0.00250
# Time:                        11:39:18   Log-Likelihood:                -4718.2
# No. Observations:                 887   AIC:                             9442.
# Df Residuals:                     884   BIC:                             9457.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     24.9456      6.263      3.983      0.000      12.654      37.237
# Age            0.0671      0.395      0.170      0.865      -0.708       0.842
# Age_2          0.0050      0.006      0.872      0.383      -0.006       0.016
# ==============================================================================
# Omnibus:                      904.339   Durbin-Watson:                   2.019
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            45198.822
# Skew:                           4.803   Prob(JB):                         0.00
# Kurtosis:                      36.626   Cond. No.                     5.43e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.43e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Interpretation

# %%
# Out:
# The in-sample MSE of this model is: 2442.120741659226

# %% [markdown]
# ### Model 5

# %%
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     6.944
# Date:                Mon, 18 Oct 2021   Prob (F-statistic):           0.000127
# Time:                        11:39:18   Log-Likelihood:                -4713.8
# No. Observations:                 887   AIC:                             9436.
# Df Residuals:                     883   BIC:                             9455.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     39.4081      7.940      4.963      0.000      23.825      54.991
# Age           -2.1445      0.848     -2.528      0.012      -3.809      -0.480
# Age_2          0.0861      0.028      3.060      0.002       0.031       0.141
# Age_3         -0.0008      0.000     -2.943      0.003      -0.001      -0.000
# ==============================================================================
# Omnibus:                      908.839   Durbin-Watson:                   2.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            46060.007
# Skew:                           4.838   Prob(JB):                         0.00
# Kurtosis:                      36.951   Cond. No.                     3.66e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.66e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Interpretation

# %%
# Out:
# The in-sample MSE of this model is: 2418.4044509511514

# %% [markdown]
# ### Which model best predicts `Fare`?

# %% [markdown]
# ## Part 3 - Classification
#
# - Using the pacakge [Statsmodels](https://www.statsmodels.org/stable/example_formulas.html) and OLS regression (linear probability model), regress `Survived` on `Pclass  + Sex + Age + Fare + nameLength`
#
#
# - Repeat the operation using the [Probit model](https://www.statsmodels.org/stable/generated/statsmodels.formula.api.probit.html)
#
#
# - Note that you will need to create dummy variables for `Pclass` and `Sex` using Pandas [get_dummies](https://pandas.pydata.org/docs/reference/api/pandas.get_dummies.html) function. You only need to do this once for both models
#
#
# - Compare, in a markdown cell, the mean absolute errors of both models

# %%
# Create dummies

df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  fam_aboard     Fare  nameLength  \
# 0    male  22.0                        1           0   7.2500          22
# 1  female  38.0                        1           0  71.2833          50
# 2  female  26.0                        0           0   7.9250          21
# 3  female  35.0                        1           0  53.1000          43
# 4    male  35.0                        0           0   8.0500          23
#
#    nameLength_Age  ln_nameLength   Age_2    Age_3  Pclass_2  Pclass_3  male
# 0           484.0       3.091042   484.0  10648.0         0         1     1
# 1          1900.0       3.912023  1444.0  54872.0         0         0     0
# 2           546.0       3.044522   676.0  17576.0         0         1     0
# 3          1505.0       3.761200  1225.0  42875.0         0         0     0
# 4           805.0       3.135494  1225.0  42875.0         0         1     1

# %% [markdown]
# ### Linear Probability Model

# %%
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Survived   R-squared:                       0.384
# Model:                            OLS   Adj. R-squared:                  0.379
# Method:                 Least Squares   F-statistic:                     91.24
# Date:                Mon, 18 Oct 2021   Prob (F-statistic):           5.33e-89
# Time:                        11:39:18   Log-Likelihood:                -405.39
# No. Observations:                 887   AIC:                             824.8
# Df Residuals:                     880   BIC:                             858.3
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.0652      0.078     13.594      0.000       0.911       1.219
# Pclass_2      -0.1851      0.045     -4.084      0.000      -0.274      -0.096
# Pclass_3      -0.3768      0.043     -8.813      0.000      -0.461      -0.293
# male          -0.4865      0.031    -15.902      0.000      -0.547      -0.426
# Age           -0.0050      0.001     -4.894      0.000      -0.007      -0.003
# Fare        5.246e-05      0.000      0.160      0.873      -0.001       0.001
# nameLength     0.0010      0.002      0.598      0.550      -0.002       0.004
# ==============================================================================
# Omnibus:                       33.669   Durbin-Watson:                   1.916
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.694
# Skew:                           0.496   Prob(JB):                     1.08e-08
# Kurtosis:                       3.085   Cond. No.                         455.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Out:
# The in-sample MAE of this model is: 31.928988327084088

# %% [markdown]
# ### Probit

# %%
# Out:
# Optimization terminated successfully.
#          Current function value: 0.451569
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Survived   No. Observations:                  887
# Model:                          Logit   Df Residuals:                      880
# Method:                           MLE   Df Model:                            6
# Date:                Mon, 18 Oct 2021   Pseudo R-squ.:                  0.3227
# Time:                        11:39:18   Log-Likelihood:                -400.54
# converged:                       True   LL-Null:                       -591.38
# Covariance Type:            nonrobust   LLR p-value:                 2.415e-79
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.3666      0.538      6.263      0.000       2.313       4.420
# Pclass_2      -1.1705      0.292     -4.014      0.000      -1.742      -0.599
# Pclass_3      -2.4122      0.295     -8.189      0.000      -2.990      -1.835
# male          -2.5288      0.204    -12.391      0.000      -2.929      -2.129
# Age           -0.0344      0.007     -4.755      0.000      -0.049      -0.020
# Fare           0.0003      0.002      0.160      0.873      -0.004       0.004
# nameLength     0.0076      0.011      0.685      0.493      -0.014       0.029
# ==============================================================================

# %%
# Out:
# The in-sample MAE of this model is: 31.928941559039632

# %% [markdown]
# ### Compare the mean absolute errors of both models
