# %% [markdown]
# # <div align="center"> SPECIAL TOPICS III </div>
# ## <div align="center"> Data Science for Social Scientists  </div>
# ### <div align="center"> ECO 4199 </div>
# ### <div align="center"> 21 September 2021 </div>
# <div align="center"> Fabien Forge, (he/him)</div>

# %% [markdown]
# ## Pandas
#
# Today we will look at a Package called [Pandas](https://pandas.pydata.org/docs/)
#
# - Packages are a collection of functions
# - Pandas is the best available package to handle data
# - It is built on an other famous package [Numpy](https://numpy.org/devdocs/user/quickstart.html)

# %%
li=[]
type(li)
# Out:
# list

# %%
li=["hello",12,"3.1"]
li
# Out:
# ['hello', 12, '3.1']

# %%
di={"hello":["bonjour","hola"]}
di['hello']
# Out:
# ['bonjour', 'hola']

# %%
# import numpy package and give it the usual alias: np
import numpy as np
print(np.__version__)
# Out:
# 1.20.1

# %% [markdown]
# ## In class exercise
# - import the Pandas library
# - use the pd alias
# - print out the Pandas version

# %%
# import the library
import pandas as pd
print(pd.__version__)
# Out:
# 1.2.3

# %% [markdown]
# ## Numpy
# - We will not go into the details of the Numpy package
# - But you might find it useful to know it exists
# - Let's demonstrate why we will use packages instead of making our own functions

# %%
# Use list comprehension to create a list from 1 to 1 million
x_list=[i for i in range(1,1000001)]
# Create the equivalent numpy array
x_np=np.array(x_list)
# print type of each list
print(type(x_list), type(x_np), sep=', ')
# Out:
# <class 'list'>, <class 'numpy.ndarray'>

# %% [markdown]
# ## Jupyter (IPython) magic
# - In Jupyter notebooks you can built-in commands named [__magic__](https://ipython.readthedocs.io/en/stable/interactive/magics.html)
# - To activate a magic command simply put a % in front
# - Let's illustrate using the __%time__ magic command

# %%
# time the runtime to sum the Python list using the base sum() function
# %time
sum(x_list)
# Out:
# Wall time: 0 ns
# 500000500000

# %% [markdown]
# ## In class exercise
# - Numpy has a sum function
# - class the sum function from numpy on x_np
# - Make sure to time the execution

# %%
# time the runtime to sum the numpy array using the sum function from numpy
# %time
np.sum(x_np)
# Out:
# Wall time: 0 ns
# 1784293664

# %% [markdown]
# ## How to use packages
# - The command [np.sum()](https://numpy.org/doc/stable/reference/generated/numpy.sum.html)  asks python to access the sum() function in the Numpy package
# - All functions in packages are accessed the same way.
# - Let's go back to Pandas!

# %% [markdown]
# ## Pandas' raison d'être
#
# - Pandas keeps the speed of Numpy
# - Then adds the ability to label __variables__ and __index__ rows in a user friendly way
# - Before loading an actual dataset into memory let's see a very simple example

# %%
# Create a small dictionary for data
d = {'col1': [1, 2, 10,20], 'col2': [3, 4, 25.0,'ottawa']}
dataframe = pd.DataFrame(data=d)
dataframe
# Out:
#    col1    col2
# 0     1       3
# 1     2       4
# 2    10    25.0
# 3    20  ottawa

# %% [markdown]
# - Your dataframe is now assigned to _dataframe_
# - This is what's known as an __object__
#     - You can learn more about [Object Oriented Programming here](https://realpython.com/python3-object-oriented-programming/)

# %%
# Use the columns attribute on the dataframe to list variables
dataframe.columns
# Out:
# Index(['col1', 'col2'], dtype='object')

# %%
# print type of what is returned by calling columns
print(type(dataframe.columns))
# Save column names to a list using the tolist method
cols=dataframe.columns.tolist()
# print the type of this list
print(type(cols))
#return the columns
cols
# Out:
# <class 'pandas.core.indexes.base.Index'>
# <class 'list'>
# ['col1', 'col2']

# %% [markdown]
# ## In class exercise
#
# - Data frames have also an index attribute
# - print out this index
# - save it into a list
# - loop over the list and print out the values

# %%
# Use the index attribute on the dataframe to list indices
display(dataframe.index)
indices=dataframe.index.tolist()
for i in indices:
    print(i)
# Out:
# RangeIndex(start=0, stop=4, step=1)
# 0
# 1
# 2
# 3

# %% [markdown]
# # Let's use real data
# - Let's look into a dataset freely available on [Open Canada](https://www.kaggle.com)
# - Specifically, we will look into data related to [COVID19 in Canada](https://open.canada.ca/data/en/dataset/b8d1d622-1ceb-4c1c-96e9-a0b38939080b)

# %% [markdown]
# Best practice

# %%
# If you access multiple times the same folder or if you want to share your code
pathFolder="~/Dropbox/Data Science for Social Scientists/Classes/Class 2 - Tidy Data/COVID/"

# %%
# read_csv into a pandas datframe
covidFile=''.join([pathFolder,"covid19_map.csv"])
pd.read_csv(covidFile)

# altenatively, if you don't have access to the file you can dowload directly from this Dropbox link:
#pd.read_csv("https://www.dropbox.com/s/78h5e3xj36xl9eu/covid19_map.csv?dl=1")
# Out:
#       pruid                  prname                   prnameFR        date  \
# 0        35                 Ontario                    Ontario  31-01-2020
# 1        59        British Columbia       Colombie-Britannique  31-01-2020
# 2         1                  Canada                     Canada  31-01-2020
# 3        35                 Ontario                    Ontario  08-02-2020
# 4        59        British Columbia       Colombie-Britannique  08-02-2020
# ...     ...                     ...                        ...         ...
# 4747     60                   Yukon                      Yukon  17-01-2021
# 4748     61   Northwest Territories  Territoires du Nord-Ouest  17-01-2021
# 4749     62                 Nunavut                    Nunavut  17-01-2021
# 4750     99  Repatriated travellers        Voyageurs rapatriés  17-01-2021
# 4751      1                  Canada                     Canada  17-01-2021
#
#       update  numconf  numprob  numdeaths  numtotal   numtested  ...  \
# 0        NaN        3        0        0.0         3         NaN  ...
# 1        NaN        1        0        0.0         1         NaN  ...
# 2        NaN        4        0        0.0         4         NaN  ...
# 3        NaN        3        0        0.0         3         NaN  ...
# 4        NaN        4        0        0.0         4         NaN  ...
# ...      ...      ...      ...        ...       ...         ...  ...
# 4747     0.0       70        0        1.0        70      6256.0  ...
# 4748     1.0       28        0        0.0        28      8323.0  ...
# 4749     0.0      266        0        1.0       266      6558.0  ...
# 4750     NaN       13        0        0.0        13        76.0  ...
# 4751     NaN   708619        0    18014.0    708619  16557083.0  ...
#
#       numdeaths_last14  ratedeaths_last14  numtotal_last7  ratetotal_last7  \
# 0                  NaN                NaN             NaN              NaN
# 1                  NaN                NaN             NaN              NaN
# 2                  NaN                NaN             NaN              NaN
# 3                  NaN                NaN             NaN              NaN
# 4                  NaN                NaN             NaN              NaN
# ...                ...                ...             ...              ...
# 4747               0.0               0.00             0.0             0.00
# 4748               0.0               0.00             4.0             8.92
# 4749               0.0               0.00             0.0             0.00
# 4750               0.0                NaN             0.0              NaN
# 4751            2103.0               5.59         47285.0           125.79
#
#       numdeaths_last7  ratedeaths_last7  avgtotal_last7  avgincidence_last7  \
# 0                 NaN               NaN             NaN                 NaN
# 1                 NaN               NaN             NaN                 NaN
# 2                 NaN               NaN             NaN                 NaN
# 3                 NaN               NaN             NaN                 NaN
# 4                 NaN               NaN             NaN                 NaN
# ...               ...               ...             ...                 ...
# 4747              0.0              0.00             0.0                0.00
# 4748              0.0              0.00             1.0                1.27
# 4749              0.0              0.00             0.0                0.00
# 4750              0.0               NaN             0.0                 NaN
# 4751           1001.0              2.66          6755.0               17.97
#
#       avgdeaths_last7  avgratedeaths_last7
# 0                 NaN                  NaN
# 1                 NaN                  NaN
# 2                 NaN                  NaN
# 3                 NaN                  NaN
# 4                 NaN                  NaN
# ...               ...                  ...
# 4747              0.0                 0.00
# 4748              0.0                 0.00
# 4749              0.0                 0.00
# 4750              0.0                  NaN
# 4751            143.0                 0.38
#
# [4752 rows x 36 columns]

# %% [markdown]
# Where did my dataset go?

# %% [markdown]
# ## Pandas dataframe
# You want to keep the data into a Pandas dataframe so you will assign it!

# %%
covidFile="https://www.dropbox.com/s/78h5e3xj36xl9eu/covid19_map.csv?dl=1"
df=pd.read_csv(covidFile)

# %% [markdown]
# ## head()
# - A method is a function that takes as a first argument, the object itself
# - Let's explore this dataset using the [head()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.head.html) method

# %%
# call the dataframe's head
df.head()
# Out:
#    pruid            prname              prnameFR        date  update  numconf  \
# 0     35           Ontario               Ontario  31-01-2020     NaN        3
# 1     59  British Columbia  Colombie-Britannique  31-01-2020     NaN        1
# 2      1            Canada                Canada  31-01-2020     NaN        4
# 3     35           Ontario               Ontario  08-02-2020     NaN        3
# 4     59  British Columbia  Colombie-Britannique  08-02-2020     NaN        4
#
#    numprob  numdeaths  numtotal  numtested  ...  numdeaths_last14  \
# 0        0        0.0         3        NaN  ...               NaN
# 1        0        0.0         1        NaN  ...               NaN
# 2        0        0.0         4        NaN  ...               NaN
# 3        0        0.0         3        NaN  ...               NaN
# 4        0        0.0         4        NaN  ...               NaN
#
#    ratedeaths_last14  numtotal_last7  ratetotal_last7  numdeaths_last7  \
# 0                NaN             NaN              NaN              NaN
# 1                NaN             NaN              NaN              NaN
# 2                NaN             NaN              NaN              NaN
# 3                NaN             NaN              NaN              NaN
# 4                NaN             NaN              NaN              NaN
#
#    ratedeaths_last7  avgtotal_last7  avgincidence_last7  avgdeaths_last7  \
# 0               NaN             NaN                 NaN              NaN
# 1               NaN             NaN                 NaN              NaN
# 2               NaN             NaN                 NaN              NaN
# 3               NaN             NaN                 NaN              NaN
# 4               NaN             NaN                 NaN              NaN
#
#    avgratedeaths_last7
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 36 columns]

# %% [markdown]
# - head() will print the first 5 rows
# - We have 36 columns but only a subset of them were printed out
# - You can change this as an [option](https://pandas.pydata.org/pandas-docs/stable/user_guide/options.html)

# %%
# Change the maximum display option
pd.set_option("display.max_columns", 999)
#print again the head
df.head()
# Out:
#    pruid            prname              prnameFR        date  update  numconf  \
# 0     35           Ontario               Ontario  31-01-2020     NaN        3
# 1     59  British Columbia  Colombie-Britannique  31-01-2020     NaN        1
# 2      1            Canada                Canada  31-01-2020     NaN        4
# 3     35           Ontario               Ontario  08-02-2020     NaN        3
# 4     59  British Columbia  Colombie-Britannique  08-02-2020     NaN        4
#
#    numprob  numdeaths  numtotal  numtested  numrecover  percentrecover  \
# 0        0        0.0         3        NaN         NaN             NaN
# 1        0        0.0         1        NaN         NaN             NaN
# 2        0        0.0         4        NaN         NaN             NaN
# 3        0        0.0         3        NaN         NaN             NaN
# 4        0        0.0         4        NaN         NaN             NaN
#
#    ratetested  numtoday  percentoday  ratetotal  ratedeaths  numdeathstoday  \
# 0         NaN         3        300.0       0.02         0.0             0.0
# 1         NaN         1        100.0       0.02         0.0             0.0
# 2         NaN         4        400.0       0.01         0.0             0.0
# 3         NaN         0          0.0       0.02         0.0             0.0
# 4         NaN         3        300.0       0.08         0.0             0.0
#
#    percentdeath  numtestedtoday  numrecoveredtoday  percentactive  numactive  \
# 0           0.0             NaN                NaN          100.0        3.0
# 1           0.0             NaN                NaN          100.0        1.0
# 2           0.0             NaN                NaN          100.0        4.0
# 3           0.0             NaN                NaN          100.0        3.0
# 4           0.0             NaN                NaN          100.0        4.0
#
#    rateactive  numtotal_last14  ratetotal_last14  numdeaths_last14  \
# 0        0.02              NaN               NaN               NaN
# 1        0.02              NaN               NaN               NaN
# 2        0.01              NaN               NaN               NaN
# 3        0.02              NaN               NaN               NaN
# 4        0.08              NaN               NaN               NaN
#
#    ratedeaths_last14  numtotal_last7  ratetotal_last7  numdeaths_last7  \
# 0                NaN             NaN              NaN              NaN
# 1                NaN             NaN              NaN              NaN
# 2                NaN             NaN              NaN              NaN
# 3                NaN             NaN              NaN              NaN
# 4                NaN             NaN              NaN              NaN
#
#    ratedeaths_last7  avgtotal_last7  avgincidence_last7  avgdeaths_last7  \
# 0               NaN             NaN                 NaN              NaN
# 1               NaN             NaN                 NaN              NaN
# 2               NaN             NaN                 NaN              NaN
# 3               NaN             NaN                 NaN              NaN
# 4               NaN             NaN                 NaN              NaN
#
#    avgratedeaths_last7
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %% [markdown]
# ## In class exercise
#
# - There is also a [tail()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.tail.html) method
# - It works like head()
# - By default the number of rows displayed is 5
# - You can change this by calling n=X inside the method
# - Call the tail() method on your dataset and print out the 10 last rows

# %%
df.tail(n=10)
# Out:
#       pruid                     prname                   prnameFR        date  \
# 4742     24                     Quebec                     Québec  17-01-2021
# 4743     10  Newfoundland and Labrador    Terre-Neuve-et-Labrador  17-01-2021
# 4744     13              New Brunswick          Nouveau-Brunswick  17-01-2021
# 4745     12                Nova Scotia            Nouvelle-Écosse  17-01-2021
# 4746     11       Prince Edward Island      Île-du-Prince-Édouard  17-01-2021
# 4747     60                      Yukon                      Yukon  17-01-2021
# 4748     61      Northwest Territories  Territoires du Nord-Ouest  17-01-2021
# 4749     62                    Nunavut                    Nunavut  17-01-2021
# 4750     99     Repatriated travellers        Voyageurs rapatriés  17-01-2021
# 4751      1                     Canada                     Canada  17-01-2021
#
#       update  numconf  numprob  numdeaths  numtotal   numtested  numrecover  \
# 4742     1.0   242714        0     9055.0    242714   2656534.0    213008.0
# 4743     1.0      396        0        4.0       396     76369.0       383.0
# 4744     1.0      947        0       12.0       947    128277.0       642.0
# 4745     1.0     1558        0       65.0      1558    195810.0      1464.0
# 4746     0.0      104        0        0.0       104     86220.0        95.0
# 4747     0.0       70        0        1.0        70      6256.0        67.0
# 4748     1.0       28        0        0.0        28      8323.0        24.0
# 4749     0.0      266        0        1.0       266      6558.0       265.0
# 4750     NaN       13        0        0.0        13        76.0        13.0
# 4751     NaN   708619        0    18014.0    708619  16557083.0    615324.0
#
#       percentrecover  ratetested  numtoday  percentoday  ratetotal  \
# 4742           87.76    313087.0      1744         0.72    2860.52
# 4743           96.72    146429.0         1         0.25      75.93
# 4744           67.79    165129.0        36         3.95     121.91
# 4745           93.97    201576.0         4         0.26     160.39
# 4746           91.35    549357.0         0         0.00      66.26
# 4747           95.71    153131.0         0         0.00     171.34
# 4748           85.71    185673.0         3        12.00      62.46
# 4749           99.62    169108.0         0         0.00     685.92
# 4750          100.00         NaN         0         0.00        NaN
# 4751           86.83    440474.0      6436         0.92    1885.16
#
#       ratedeaths  numdeathstoday  percentdeath  numtestedtoday  \
# 4742      106.72            50.0          3.73          9270.0
# 4743        0.77             0.0          1.01           204.0
# 4744        1.54             0.0          1.27           874.0
# 4745        6.69             0.0          4.17           743.0
# 4746        0.00             0.0          0.00           331.0
# 4747        2.45             0.0          1.43             0.0
# 4748        0.00             0.0          0.00             0.0
# 4749        2.58             0.0          0.38             0.0
# 4750         NaN             0.0          0.00             0.0
# 4751       47.92           149.0          2.54         70499.0
#
#       numrecoveredtoday  percentactive  numactive  rateactive  \
# 4742             2644.0           8.51    20651.0      243.38
# 4743                0.0           2.27        9.0        1.73
# 4744               11.0          30.94      293.0       37.72
# 4745                5.0           1.86       29.0        2.99
# 4746                0.0           8.65        9.0        5.73
# 4747                0.0           2.86        2.0        4.90
# 4748                0.0          14.29        4.0        8.92
# 4749                0.0           0.00        0.0        0.00
# 4750                0.0           0.00        0.0         NaN
# 4751             7240.0          10.62    75281.0      200.27
#
#       numtotal_last14  ratetotal_last14  numdeaths_last14  ratedeaths_last14  \
# 4742          32410.0            381.97             708.0               8.34
# 4743              6.0              1.15               0.0               0.00
# 4744            329.0             42.35               3.0               0.39
# 4745             57.0              5.87               0.0               0.00
# 4746              8.0              5.10               0.0               0.00
# 4747              6.0             14.69               0.0               0.00
# 4748              4.0              8.92               0.0               0.00
# 4749              0.0              0.00               0.0               0.00
# 4750              0.0               NaN               0.0                NaN
# 4751         105106.0            279.62            2103.0               5.59
#
#       numtotal_last7  ratetotal_last7  numdeaths_last7  ratedeaths_last7  \
# 4742         13893.0           163.74            369.0              4.35
# 4743             3.0             0.58              0.0              0.00
# 4744           168.0            21.63              3.0              0.39
# 4745            30.0             3.09              0.0              0.00
# 4746             2.0             1.27              0.0              0.00
# 4747             0.0             0.00              0.0              0.00
# 4748             4.0             8.92              0.0              0.00
# 4749             0.0             0.00              0.0              0.00
# 4750             0.0              NaN              0.0               NaN
# 4751         47285.0           125.79           1001.0              2.66
#
#       avgtotal_last7  avgincidence_last7  avgdeaths_last7  avgratedeaths_last7
# 4742          1985.0               23.39             53.0                 0.62
# 4743             0.0                0.08              0.0                 0.00
# 4744            24.0                3.09              0.0                 0.06
# 4745             4.0                0.44              0.0                 0.00
# 4746             0.0                0.18              0.0                 0.00
# 4747             0.0                0.00              0.0                 0.00
# 4748             1.0                1.27              0.0                 0.00
# 4749             0.0                0.00              0.0                 0.00
# 4750             0.0                 NaN              0.0                  NaN
# 4751          6755.0               17.97            143.0                 0.38

# %% [markdown]
# ## Shape
#
# - Let's get a better sense of the number of variables (columns) and observations (rows) in this dataset.
# - To do so you can use the [shape](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.shape.html) __attribute__

# %%
# What are the dimensions of our df?
df.shape # <- 4.752 observations and 36 variables
# Out:
# (4752, 36)

# %% [markdown]
# ## Info()
# Last week we talked about the different types.
#
# Pandas offer a way to know about the type of each variable and more.
#
# This is the [info()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.info.html) method

# %%
# Call info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4752 entries, 0 to 4751
# Data columns (total 36 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   pruid                4752 non-null   int64
#  1   prname               4752 non-null   object
#  2   prnameFR             4752 non-null   object
#  3   date                 4752 non-null   object
#  4   update               325 non-null    float64
#  5   numconf              4752 non-null   int64
#  6   numprob              4752 non-null   int64
#  7   numdeaths            4633 non-null   float64
#  8   numtotal             4752 non-null   int64
#  9   numtested            4695 non-null   float64
#  10  numrecover           4228 non-null   float64
#  11  percentrecover       4024 non-null   float64
#  12  ratetested           4370 non-null   float64
#  13  numtoday             4752 non-null   int64
#  14  percentoday          4752 non-null   float64
#  15  ratetotal            4439 non-null   float64
#  16  ratedeaths           4439 non-null   float64
#  17  numdeathstoday       4633 non-null   float64
#  18  percentdeath         4355 non-null   float64
#  19  numtestedtoday       4695 non-null   float64
#  20  numrecoveredtoday    4228 non-null   float64
#  21  percentactive        4355 non-null   float64
#  22  numactive            4355 non-null   float64
#  23  rateactive           4439 non-null   float64
#  24  numtotal_last14      4500 non-null   float64
#  25  ratetotal_last14     4200 non-null   float64
#  26  numdeaths_last14     4500 non-null   float64
#  27  ratedeaths_last14    4200 non-null   float64
#  28  numtotal_last7       4500 non-null   float64
#  29  ratetotal_last7      4200 non-null   float64
#  30  numdeaths_last7      4500 non-null   float64
#  31  ratedeaths_last7     4199 non-null   float64
#  32  avgtotal_last7       4500 non-null   float64
#  33  avgincidence_last7   4200 non-null   float64
#  34  avgdeaths_last7      4500 non-null   float64
#  35  avgratedeaths_last7  4200 non-null   float64
# dtypes: float64(28), int64(5), object(3)
# memory usage: 1.3+ MB

# %% [markdown]
# ## describe()
#
# - You can also obtain a few summary statistics
#
# - These are of course available only for numerical variables

# %%
# use the describe method on df
df.describe()
# Out:
#              pruid      update        numconf      numprob     numdeaths  \
# count  4752.000000  325.000000    4752.000000  4752.000000   4633.000000
# mean     39.105219    0.843077   24741.714646     1.381313   1138.887114
# std      26.255321    0.364289   70018.190902    19.118740   2730.359788
# min       1.000000    0.000000       0.000000     0.000000      0.000000
# 25%      12.000000    1.000000      17.000000     0.000000      0.000000
# 50%      46.000000    1.000000     339.500000     0.000000      7.000000
# 75%      60.000000    1.000000   11863.750000     0.000000    237.000000
# max      99.000000    1.000000  708619.000000   833.000000  18014.000000
#
#             numtotal     numtested     numrecover  percentrecover  \
# count    4752.000000  4.695000e+03    4228.000000     4024.000000
# mean    24742.271254  7.732262e+05   22129.917928       82.951817
# std     70018.280135  2.094634e+06   61349.783745       20.261694
# min         0.000000  0.000000e+00       0.000000        0.000000
# 25%        20.000000  4.134000e+03      27.000000       79.130000
# 50%       341.000000  5.447700e+04     453.500000       88.350000
# 75%     11863.750000  3.442590e+05   12047.250000       96.610000
# max    708619.000000  1.655708e+07  615324.000000      100.000000
#
#           ratetested    numtoday  percentoday    ratetotal   ratedeaths  \
# count    4370.000000  4752.00000  4752.000000  4439.000000  4439.000000
# mean   113185.255835   298.24032     3.296311   265.906972     9.222600
# std    113188.143668   908.89144    17.619229   461.171685    18.163914
# min        26.000000    -4.00000    -0.690000     0.000000     0.000000
# 25%     32271.250000     0.00000     0.000000    21.945000     0.000000
# 50%     76245.000000     1.00000     0.270000    59.610000     0.940000
# 75%    151229.250000   133.00000     1.450000   270.820000     6.690000
# max    681640.000000  8766.00000   600.000000  2860.520000   106.720000
#
#        numdeathstoday  percentdeath  numtestedtoday  numrecoveredtoday  \
# count     4633.000000   4355.000000     4695.000000        4228.000000
# mean         7.776171      2.358721     7053.064324         293.388600
# std         23.848194      2.647800    17923.324886        1060.266863
# min         -2.000000      0.000000   -20682.000000         -31.000000
# 25%          0.000000      0.000000       14.000000           0.000000
# 50%          0.000000      1.330000      394.000000           1.000000
# 75%          2.000000      3.975000     3603.500000         117.000000
# max        222.000000      9.990000   255537.000000       23853.000000
#
#        percentactive     numactive   rateactive  numtotal_last14  \
# count    4355.000000   4355.000000  4439.000000      4500.000000
# mean       22.831330   4301.495752    48.356515      4116.473778
# std        31.164122  11008.301342    97.466843     12215.969140
# min         0.000000      0.000000     0.000000        -1.000000
# 25%         1.795000      3.000000     0.390000         1.000000
# 50%         9.540000     65.000000     6.900000        41.000000
# 75%        27.115000   2225.000000    34.290000      1978.750000
# max       100.000000  85549.000000   676.180000    109120.000000
#
#        ratetotal_last14  numdeaths_last14  ratedeaths_last14  numtotal_last7  \
# count        4200.00000       4500.000000        4200.000000     4500.000000
# mean           48.01305        106.221111           1.053602     2138.461778
# std            90.99019        308.458875           2.381253     6324.661007
# min            -0.19000          0.000000           0.000000       -1.000000
# 25%             0.64000          0.000000           0.000000        0.000000
# 50%             9.00000          0.000000           0.090000       18.000000
# 75%            37.01500         30.000000           0.660000     1038.000000
# max           545.44000       2311.000000          17.580000    57821.000000
#
#        ratetotal_last7  numdeaths_last7  ratedeaths_last7  avgtotal_last7  \
# count      4200.000000      4500.000000       4199.000000     4500.000000
# mean         24.818121        54.631111          0.543296      305.485333
# std          46.987089       158.396909          1.226052      903.531438
# min          -0.190000         0.000000          0.000000        0.000000
# 25%           0.190000         0.000000          0.000000        0.000000
# 50%           4.460000         0.000000          0.000000        3.000000
# 75%          19.927500        16.000000          0.335000      148.250000
# max         288.810000      1236.000000          9.100000     8260.000000
#
#        avgincidence_last7  avgdeaths_last7  avgratedeaths_last7
# count         4200.000000      4500.000000          4200.000000
# mean             3.545345         7.788444             0.077548
# std              6.712453        22.638164             0.175150
# min             -0.030000         0.000000             0.000000
# 25%              0.030000         0.000000             0.000000
# 50%              0.640000         0.000000             0.000000
# 75%              2.850000         2.000000             0.050000
# max             41.260000       177.000000             1.300000

# %% [markdown]
# ## Question
# - Why are there 33 columns returned when using describe?

# %% [markdown]
# ## In class exercise
#
# - You can chain commands in Pandas.
# - Code will be executed from letf to right
# - Print again the describe() table
# - This time make sure that the statistics form the columns and the variables are the indices
# - Hint: you can use the [transpose()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.transpose.html) method

# %%
df.describe().transpose()
# Out:
#                       count           mean           std       min        25%  \
# pruid                4752.0      39.105219  2.625532e+01      1.00     12.000
# update                325.0       0.843077  3.642891e-01      0.00      1.000
# numconf              4752.0   24741.714646  7.001819e+04      0.00     17.000
# numprob              4752.0       1.381313  1.911874e+01      0.00      0.000
# numdeaths            4633.0    1138.887114  2.730360e+03      0.00      0.000
# numtotal             4752.0   24742.271254  7.001828e+04      0.00     20.000
# numtested            4695.0  773226.182322  2.094634e+06      0.00   4134.000
# numrecover           4228.0   22129.917928  6.134978e+04      0.00     27.000
# percentrecover       4024.0      82.951817  2.026169e+01      0.00     79.130
# ratetested           4370.0  113185.255835  1.131881e+05     26.00  32271.250
# numtoday             4752.0     298.240320  9.088914e+02     -4.00      0.000
# percentoday          4752.0       3.296311  1.761923e+01     -0.69      0.000
# ratetotal            4439.0     265.906972  4.611717e+02      0.00     21.945
# ratedeaths           4439.0       9.222600  1.816391e+01      0.00      0.000
# numdeathstoday       4633.0       7.776171  2.384819e+01     -2.00      0.000
# percentdeath         4355.0       2.358721  2.647800e+00      0.00      0.000
# numtestedtoday       4695.0    7053.064324  1.792332e+04 -20682.00     14.000
# numrecoveredtoday    4228.0     293.388600  1.060267e+03    -31.00      0.000
# percentactive        4355.0      22.831330  3.116412e+01      0.00      1.795
# numactive            4355.0    4301.495752  1.100830e+04      0.00      3.000
# rateactive           4439.0      48.356515  9.746684e+01      0.00      0.390
# numtotal_last14      4500.0    4116.473778  1.221597e+04     -1.00      1.000
# ratetotal_last14     4200.0      48.013050  9.099019e+01     -0.19      0.640
# numdeaths_last14     4500.0     106.221111  3.084589e+02      0.00      0.000
# ratedeaths_last14    4200.0       1.053602  2.381253e+00      0.00      0.000
# numtotal_last7       4500.0    2138.461778  6.324661e+03     -1.00      0.000
# ratetotal_last7      4200.0      24.818121  4.698709e+01     -0.19      0.190
# numdeaths_last7      4500.0      54.631111  1.583969e+02      0.00      0.000
# ratedeaths_last7     4199.0       0.543296  1.226052e+00      0.00      0.000
# avgtotal_last7       4500.0     305.485333  9.035314e+02      0.00      0.000
# avgincidence_last7   4200.0       3.545345  6.712453e+00     -0.03      0.030
# avgdeaths_last7      4500.0       7.788444  2.263816e+01      0.00      0.000
# avgratedeaths_last7  4200.0       0.077548  1.751496e-01      0.00      0.000
#
#                           50%          75%          max
# pruid                   46.00      60.0000        99.00
# update                   1.00       1.0000         1.00
# numconf                339.50   11863.7500    708619.00
# numprob                  0.00       0.0000       833.00
# numdeaths                7.00     237.0000     18014.00
# numtotal               341.00   11863.7500    708619.00
# numtested            54477.00  344259.0000  16557083.00
# numrecover             453.50   12047.2500    615324.00
# percentrecover          88.35      96.6100       100.00
# ratetested           76245.00  151229.2500    681640.00
# numtoday                 1.00     133.0000      8766.00
# percentoday              0.27       1.4500       600.00
# ratetotal               59.61     270.8200      2860.52
# ratedeaths               0.94       6.6900       106.72
# numdeathstoday           0.00       2.0000       222.00
# percentdeath             1.33       3.9750         9.99
# numtestedtoday         394.00    3603.5000    255537.00
# numrecoveredtoday        1.00     117.0000     23853.00
# percentactive            9.54      27.1150       100.00
# numactive               65.00    2225.0000     85549.00
# rateactive               6.90      34.2900       676.18
# numtotal_last14         41.00    1978.7500    109120.00
# ratetotal_last14         9.00      37.0150       545.44
# numdeaths_last14         0.00      30.0000      2311.00
# ratedeaths_last14        0.09       0.6600        17.58
# numtotal_last7          18.00    1038.0000     57821.00
# ratetotal_last7          4.46      19.9275       288.81
# numdeaths_last7          0.00      16.0000      1236.00
# ratedeaths_last7         0.00       0.3350         9.10
# avgtotal_last7           3.00     148.2500      8260.00
# avgincidence_last7       0.64       2.8500        41.26
# avgdeaths_last7          0.00       2.0000       177.00
# avgratedeaths_last7      0.00       0.0500         1.30

# %% [markdown]
# ## Subsetting
# - It is very unlikely that a dataset, you didn't create yourself, will be tailored to your exact needs
# - __Data cleaning__ consist in removing, reshaping, creating and merging data
# - Let's start with using a subset of the data

# %%
# call head again
df.head()
# Out:
#    pruid            prname              prnameFR        date  update  numconf  \
# 0     35           Ontario               Ontario  31-01-2020     NaN        3
# 1     59  British Columbia  Colombie-Britannique  31-01-2020     NaN        1
# 2      1            Canada                Canada  31-01-2020     NaN        4
# 3     35           Ontario               Ontario  08-02-2020     NaN        3
# 4     59  British Columbia  Colombie-Britannique  08-02-2020     NaN        4
#
#    numprob  numdeaths  numtotal  numtested  numrecover  percentrecover  \
# 0        0        0.0         3        NaN         NaN             NaN
# 1        0        0.0         1        NaN         NaN             NaN
# 2        0        0.0         4        NaN         NaN             NaN
# 3        0        0.0         3        NaN         NaN             NaN
# 4        0        0.0         4        NaN         NaN             NaN
#
#    ratetested  numtoday  percentoday  ratetotal  ratedeaths  numdeathstoday  \
# 0         NaN         3        300.0       0.02         0.0             0.0
# 1         NaN         1        100.0       0.02         0.0             0.0
# 2         NaN         4        400.0       0.01         0.0             0.0
# 3         NaN         0          0.0       0.02         0.0             0.0
# 4         NaN         3        300.0       0.08         0.0             0.0
#
#    percentdeath  numtestedtoday  numrecoveredtoday  percentactive  numactive  \
# 0           0.0             NaN                NaN          100.0        3.0
# 1           0.0             NaN                NaN          100.0        1.0
# 2           0.0             NaN                NaN          100.0        4.0
# 3           0.0             NaN                NaN          100.0        3.0
# 4           0.0             NaN                NaN          100.0        4.0
#
#    rateactive  numtotal_last14  ratetotal_last14  numdeaths_last14  \
# 0        0.02              NaN               NaN               NaN
# 1        0.02              NaN               NaN               NaN
# 2        0.01              NaN               NaN               NaN
# 3        0.02              NaN               NaN               NaN
# 4        0.08              NaN               NaN               NaN
#
#    ratedeaths_last14  numtotal_last7  ratetotal_last7  numdeaths_last7  \
# 0                NaN             NaN              NaN              NaN
# 1                NaN             NaN              NaN              NaN
# 2                NaN             NaN              NaN              NaN
# 3                NaN             NaN              NaN              NaN
# 4                NaN             NaN              NaN              NaN
#
#    ratedeaths_last7  avgtotal_last7  avgincidence_last7  avgdeaths_last7  \
# 0               NaN             NaN                 NaN              NaN
# 1               NaN             NaN                 NaN              NaN
# 2               NaN             NaN                 NaN              NaN
# 3               NaN             NaN                 NaN              NaN
# 4               NaN             NaN                 NaN              NaN
#
#    avgratedeaths_last7
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %% [markdown]
# ## Keep only the columns that you need
# - Often you will want to remove columns (variables)
# - Columns that are not needed may take space and slow down your code
# - Let's use the [pop](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.pop.html) method on prnameFR variable

# %%
# you can use the pop method by using the variable's name
print(df.columns)
df.pop('prnameFR')
print(df.columns)
# Out:
# Index(['pruid', 'prname', 'prnameFR', 'date', 'update', 'numconf', 'numprob',
#        'numdeaths', 'numtotal', 'numtested', 'numrecover', 'percentrecover',
#        'ratetested', 'numtoday', 'percentoday', 'ratetotal', 'ratedeaths',
#        'numdeathstoday', 'percentdeath', 'numtestedtoday', 'numrecoveredtoday',
#        'percentactive', 'numactive', 'rateactive', 'numtotal_last14',
#        'ratetotal_last14', 'numdeaths_last14', 'ratedeaths_last14',
#        'numtotal_last7', 'ratetotal_last7', 'numdeaths_last7',
#        'ratedeaths_last7', 'avgtotal_last7', 'avgincidence_last7',
#        'avgdeaths_last7', 'avgratedeaths_last7'],
#       dtype='object')
# Index(['pruid', 'prname', 'date', 'update', 'numconf', 'numprob', 'numdeaths',
#        'numtotal', 'numtested', 'numrecover', 'percentrecover', 'ratetested',
#        'numtoday', 'percentoday', 'ratetotal', 'ratedeaths', 'numdeathstoday',
#        'percentdeath', 'numtestedtoday', 'numrecoveredtoday', 'percentactive',
#        'numactive', 'rateactive', 'numtotal_last14', 'ratetotal_last14',
#        'numdeaths_last14', 'ratedeaths_last14', 'numtotal_last7',
#        'ratetotal_last7', 'numdeaths_last7', 'ratedeaths_last7',
#        'avgtotal_last7', 'avgincidence_last7', 'avgdeaths_last7',
#        'avgratedeaths_last7'],
#       dtype='object')

# %% [markdown]
# ## drop()
# - The [drop](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html) method allows you to drop one or more columns
# - It is more verbose
# - Let's see some of its functionalities and remove variables ending with _last7

# %%
# Let's pass a list of columns to drop
df.drop(columns=['numtotal_last7','ratetotal_last7', 'numdeaths_last7', 'ratedeaths_last7','avgtotal_last7', 'avgincidence_last7', 'avgdeaths_last7','avgratedeaths_last7'])
# Out:
#       pruid                  prname        date  update  numconf  numprob  \
# 0        35                 Ontario  31-01-2020     NaN        3        0
# 1        59        British Columbia  31-01-2020     NaN        1        0
# 2         1                  Canada  31-01-2020     NaN        4        0
# 3        35                 Ontario  08-02-2020     NaN        3        0
# 4        59        British Columbia  08-02-2020     NaN        4        0
# ...     ...                     ...         ...     ...      ...      ...
# 4747     60                   Yukon  17-01-2021     0.0       70        0
# 4748     61   Northwest Territories  17-01-2021     1.0       28        0
# 4749     62                 Nunavut  17-01-2021     0.0      266        0
# 4750     99  Repatriated travellers  17-01-2021     NaN       13        0
# 4751      1                  Canada  17-01-2021     NaN   708619        0
#
#       numdeaths  numtotal   numtested  numrecover  percentrecover  ratetested  \
# 0           0.0         3         NaN         NaN             NaN         NaN
# 1           0.0         1         NaN         NaN             NaN         NaN
# 2           0.0         4         NaN         NaN             NaN         NaN
# 3           0.0         3         NaN         NaN             NaN         NaN
# 4           0.0         4         NaN         NaN             NaN         NaN
# ...         ...       ...         ...         ...             ...         ...
# 4747        1.0        70      6256.0        67.0           95.71    153131.0
# 4748        0.0        28      8323.0        24.0           85.71    185673.0
# 4749        1.0       266      6558.0       265.0           99.62    169108.0
# 4750        0.0        13        76.0        13.0          100.00         NaN
# 4751    18014.0    708619  16557083.0    615324.0           86.83    440474.0
#
#       numtoday  percentoday  ratetotal  ratedeaths  numdeathstoday  \
# 0            3       300.00       0.02        0.00             0.0
# 1            1       100.00       0.02        0.00             0.0
# 2            4       400.00       0.01        0.00             0.0
# 3            0         0.00       0.02        0.00             0.0
# 4            3       300.00       0.08        0.00             0.0
# ...        ...          ...        ...         ...             ...
# 4747         0         0.00     171.34        2.45             0.0
# 4748         3        12.00      62.46        0.00             0.0
# 4749         0         0.00     685.92        2.58             0.0
# 4750         0         0.00        NaN         NaN             0.0
# 4751      6436         0.92    1885.16       47.92           149.0
#
#       percentdeath  numtestedtoday  numrecoveredtoday  percentactive  \
# 0             0.00             NaN                NaN         100.00
# 1             0.00             NaN                NaN         100.00
# 2             0.00             NaN                NaN         100.00
# 3             0.00             NaN                NaN         100.00
# 4             0.00             NaN                NaN         100.00
# ...            ...             ...                ...            ...
# 4747          1.43             0.0                0.0           2.86
# 4748          0.00             0.0                0.0          14.29
# 4749          0.38             0.0                0.0           0.00
# 4750          0.00             0.0                0.0           0.00
# 4751          2.54         70499.0             7240.0          10.62
#
#       numactive  rateactive  numtotal_last14  ratetotal_last14  \
# 0           3.0        0.02              NaN               NaN
# 1           1.0        0.02              NaN               NaN
# 2           4.0        0.01              NaN               NaN
# 3           3.0        0.02              NaN               NaN
# 4           4.0        0.08              NaN               NaN
# ...         ...         ...              ...               ...
# 4747        2.0        4.90              6.0             14.69
# 4748        4.0        8.92              4.0              8.92
# 4749        0.0        0.00              0.0              0.00
# 4750        0.0         NaN              0.0               NaN
# 4751    75281.0      200.27         105106.0            279.62
#
#       numdeaths_last14  ratedeaths_last14
# 0                  NaN                NaN
# 1                  NaN                NaN
# 2                  NaN                NaN
# 3                  NaN                NaN
# 4                  NaN                NaN
# ...                ...                ...
# 4747               0.0               0.00
# 4748               0.0               0.00
# 4749               0.0               0.00
# 4750               0.0                NaN
# 4751            2103.0               5.59
#
# [4752 rows x 27 columns]

# %% [markdown]
# ## Keep columns
# - What if instead you want to specify which columns to keep instead?
# - You can do so by calling a list on the dataframe
# - Say you only want to keep the province name, date and total number of positive cases

# %%
# subsetting
df[['prname','date','numtotal']]
# Out:
#                       prname        date  numtotal
# 0                    Ontario  31-01-2020         3
# 1           British Columbia  31-01-2020         1
# 2                     Canada  31-01-2020         4
# 3                    Ontario  08-02-2020         3
# 4           British Columbia  08-02-2020         4
# ...                      ...         ...       ...
# 4747                   Yukon  17-01-2021        70
# 4748   Northwest Territories  17-01-2021        28
# 4749                 Nunavut  17-01-2021       266
# 4750  Repatriated travellers  17-01-2021        13
# 4751                  Canada  17-01-2021    708619
#
# [4752 rows x 3 columns]

# %% [markdown]
# ## In class exercise
# - Save in a list named toKeep the columns corresponding to province name, date and the number of deaths
# - pass this list in df
# - save the results in a new dataframe called df_mortality
# - show the head of df_mortality

# %%
# Save vars in list
toKeep=['prname','date','numdeaths']
# pass list in dataframe and save in new dataframe
df_mortality=df[toKeep].copy() 
# show head
df_mortality.head()
# Out:
#              prname        date  numdeaths
# 0           Ontario  31-01-2020        0.0
# 1  British Columbia  31-01-2020        0.0
# 2            Canada  31-01-2020        0.0
# 3           Ontario  08-02-2020        0.0
# 4  British Columbia  08-02-2020        0.0

# %% [markdown]
# ## rename()
# - Another useful method is [rename()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rename.html)
# - rename() takes a dictionary as a _mapper_ the key represents the current variable name and the value the new variable name.
# - you can change multiple names at the same time
# - you can also set the inplace argument to True
# - Let's rename prname and numdeaths of df_mortality to province and deaths

# %%
df_mortality.rename(columns={'prname':'province','numdeaths':'deaths'},inplace=True)
df_mortality.head()
# Out:
#            province        date  deaths
# 0           Ontario  31-01-2020     0.0
# 1  British Columbia  31-01-2020     0.0
# 2            Canada  31-01-2020     0.0
# 3           Ontario  08-02-2020     0.0
# 4  British Columbia  08-02-2020     0.0

# %% [markdown]
# ## Subset of observations
# - You may also be interested in subseting the dataset according to the information it contains
# - Say only want to keep data from Ontario
# - You can do so by using booleans

# %%
# Can you guess what this will return?
df['prname']=="Ontario"
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 4747    False
# 4748    False
# 4749    False
# 4750    False
# 4751    False
# Name: prname, Length: 4752, dtype: bool

# %%
# What is the type of what is returned?
type(df['prname']=="Ontario")
# Out:
# pandas.core.series.Series

# %%
# Create a new dataframe named on as a copy of df 
on=df[df['prname']=="Ontario"].copy()
# print head
on.head()
# Out:
#     pruid   prname        date  update  numconf  numprob  numdeaths  numtotal  \
# 0      35  Ontario  31-01-2020     NaN        3        0        0.0         3
# 3      35  Ontario  08-02-2020     NaN        3        0        0.0         3
# 6      35  Ontario  16-02-2020     NaN        3        0        0.0         3
# 9      35  Ontario  21-02-2020     NaN        3        0        0.0         3
# 12     35  Ontario  24-02-2020     NaN        4        0        0.0         4
#
#     numtested  numrecover  percentrecover  ratetested  numtoday  percentoday  \
# 0         NaN         NaN             NaN         NaN         3       300.00
# 3         NaN         NaN             NaN         NaN         0         0.00
# 6         NaN         NaN             NaN         NaN         0         0.00
# 9         NaN         NaN             NaN         NaN         0         0.00
# 12        NaN         NaN             NaN         NaN         1        33.33
#
#     ratetotal  ratedeaths  numdeathstoday  percentdeath  numtestedtoday  \
# 0        0.02         0.0             0.0           0.0             NaN
# 3        0.02         0.0             0.0           0.0             NaN
# 6        0.02         0.0             0.0           0.0             NaN
# 9        0.02         0.0             0.0           0.0             NaN
# 12       0.03         0.0             0.0           0.0             NaN
#
#     numrecoveredtoday  percentactive  numactive  rateactive  numtotal_last14  \
# 0                 NaN          100.0        3.0        0.02              NaN
# 3                 NaN          100.0        3.0        0.02              NaN
# 6                 NaN          100.0        3.0        0.02              NaN
# 9                 NaN          100.0        3.0        0.02              NaN
# 12                NaN          100.0        4.0        0.03              NaN
#
#     ratetotal_last14  numdeaths_last14  ratedeaths_last14  numtotal_last7  \
# 0                NaN               NaN                NaN             NaN
# 3                NaN               NaN                NaN             NaN
# 6                NaN               NaN                NaN             NaN
# 9                NaN               NaN                NaN             NaN
# 12               NaN               NaN                NaN             NaN
#
#     ratetotal_last7  numdeaths_last7  ratedeaths_last7  avgtotal_last7  \
# 0               NaN              NaN               NaN             NaN
# 3               NaN              NaN               NaN             NaN
# 6               NaN              NaN               NaN             NaN
# 9               NaN              NaN               NaN             NaN
# 12              NaN              NaN               NaN             NaN
#
#     avgincidence_last7  avgdeaths_last7  avgratedeaths_last7
# 0                  NaN              NaN                  NaN
# 3                  NaN              NaN                  NaN
# 6                  NaN              NaN                  NaN
# 9                  NaN              NaN                  NaN
# 12                 NaN              NaN                  NaN

# %% [markdown]
# ## copy()
# - Pandas allows you to map the changes you make on a subset of a dataset to the original dataset
# - In our example, you could map the changes you make to the dataframe on onto df
# - Hence, Pandas wants you to be specific about the type of copy you are making
# - using the [copy()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.copy.html) method allows you to specify you do not want these dataframes to be linked.
# - Sorry!

# %% [markdown]
# ## unique()
# - The unique() method can be called on a [Pandas series](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html) (a single column)
# - It will return all unique values in a series

# %%
# call unique on the prname variable
df['prname'].unique()
# Out:
# array(['Ontario', 'British Columbia', 'Canada', 'Quebec', 'Alberta',
#        'Saskatchewan', 'Manitoba', 'New Brunswick',
#        'Newfoundland and Labrador', 'Nova Scotia', 'Prince Edward Island',
#        'Northwest Territories', 'Nunavut', 'Yukon',
#        'Repatriated travellers'], dtype=object)

# %% [markdown]
# ## In class exercise
# - You can combine the booleans
# - It seems like there are values in prname that are not provinces or territories
# - Subset df and keep only provinces and territories
# - hint you will need to use  "&" or "|" in between booleans and put parentheses around each condition
# - Save the results in a df2 dataframe
# - print the unique values of prname for df2
# - show the tail of the df2

# %%
df2=df[(df.prname!='Canada') & (df['prname']!='Repatriated travellers')]
display(df2.prname.unique())
df2.tail()
# Out:
# array(['Ontario', 'British Columbia', 'Quebec', 'Alberta', 'Saskatchewan',
#        'Manitoba', 'New Brunswick', 'Newfoundland and Labrador',
#        'Nova Scotia', 'Prince Edward Island', 'Northwest Territories',
#        'Nunavut', 'Yukon'], dtype=object)
#       pruid                 prname        date  update  numconf  numprob  \
# 4745     12            Nova Scotia  17-01-2021     1.0     1558        0
# 4746     11   Prince Edward Island  17-01-2021     0.0      104        0
# 4747     60                  Yukon  17-01-2021     0.0       70        0
# 4748     61  Northwest Territories  17-01-2021     1.0       28        0
# 4749     62                Nunavut  17-01-2021     0.0      266        0
#
#       numdeaths  numtotal  numtested  numrecover  percentrecover  ratetested  \
# 4745       65.0      1558   195810.0      1464.0           93.97    201576.0
# 4746        0.0       104    86220.0        95.0           91.35    549357.0
# 4747        1.0        70     6256.0        67.0           95.71    153131.0
# 4748        0.0        28     8323.0        24.0           85.71    185673.0
# 4749        1.0       266     6558.0       265.0           99.62    169108.0
#
#       numtoday  percentoday  ratetotal  ratedeaths  numdeathstoday  \
# 4745         4         0.26     160.39        6.69             0.0
# 4746         0         0.00      66.26        0.00             0.0
# 4747         0         0.00     171.34        2.45             0.0
# 4748         3        12.00      62.46        0.00             0.0
# 4749         0         0.00     685.92        2.58             0.0
#
#       percentdeath  numtestedtoday  numrecoveredtoday  percentactive  \
# 4745          4.17           743.0                5.0           1.86
# 4746          0.00           331.0                0.0           8.65
# 4747          1.43             0.0                0.0           2.86
# 4748          0.00             0.0                0.0          14.29
# 4749          0.38             0.0                0.0           0.00
#
#       numactive  rateactive  numtotal_last14  ratetotal_last14  \
# 4745       29.0        2.99             57.0              5.87
# 4746        9.0        5.73              8.0              5.10
# 4747        2.0        4.90              6.0             14.69
# 4748        4.0        8.92              4.0              8.92
# 4749        0.0        0.00              0.0              0.00
#
#       numdeaths_last14  ratedeaths_last14  numtotal_last7  ratetotal_last7  \
# 4745               0.0                0.0            30.0             3.09
# 4746               0.0                0.0             2.0             1.27
# 4747               0.0                0.0             0.0             0.00
# 4748               0.0                0.0             4.0             8.92
# 4749               0.0                0.0             0.0             0.00
#
#       numdeaths_last7  ratedeaths_last7  avgtotal_last7  avgincidence_last7  \
# 4745              0.0               0.0             4.0                0.44
# 4746              0.0               0.0             0.0                0.18
# 4747              0.0               0.0             0.0                0.00
# 4748              0.0               0.0             1.0                1.27
# 4749              0.0               0.0             0.0                0.00
#
#       avgdeaths_last7  avgratedeaths_last7
# 4745              0.0                  0.0
# 4746              0.0                  0.0
# 4747              0.0                  0.0
# 4748              0.0                  0.0
# 4749              0.0                  0.0

# %% [markdown]
# ## Combine the two
# - You can combine the column and row selection
# - Usually you would use [.loc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html)
# - The order is always rows, columns: df.loc[df.colname==value, [cols_list]]
# - Say you want data only for Quebec and only for the number of tested and the date

# %%
# create a Quebec (qc) dataset with 'prname','date','numtestedtoday' variables as a copy of df
qc=df.loc[df['prname']=="Quebec", ['prname','date','numtestedtoday']].copy()
qc.head()
# Out:
#     prname        date  numtestedtoday
# 29  Quebec  01-03-2020             NaN
# 33  Quebec  03-03-2020             NaN
# 37  Quebec  05-03-2020             NaN
# 41  Quebec  06-03-2020             NaN
# 45  Quebec  07-03-2020             NaN

# %% [markdown]
# ## Create new variables
# - Often you will also want to create new variables
# - Let's see a very simple case

# %%
# you can also create a constant very easily
qc['test']=1
qc.head()
# Out:
#     prname        date  numtestedtoday day month  year  test
# 29  Quebec  01-03-2020             NaN  01    03  2020     1
# 33  Quebec  03-03-2020             NaN  03    03  2020     1
# 37  Quebec  05-03-2020             NaN  05    03  2020     1
# 41  Quebec  06-03-2020             NaN  06    03  2020     1
# 45  Quebec  07-03-2020             NaN  07    03  2020     1

# %%
# Let's pop this series out
qc.pop('test')
# Out:
# 29      1
# 33      1
# 37      1
# 41      1
# 45      1
#        ..
# 4682    1
# 4697    1
# 4712    1
# 4727    1
# 4742    1
# Name: test, Length: 320, dtype: int64

# %%
qc.head()
# Out:
#     prname        date  numtestedtoday day month  year
# 29  Quebec  01-03-2020             NaN  01    03  2020
# 33  Quebec  03-03-2020             NaN  03    03  2020
# 37  Quebec  05-03-2020             NaN  05    03  2020
# 41  Quebec  06-03-2020             NaN  06    03  2020
# 45  Quebec  07-03-2020             NaN  07    03  2020

# %% [markdown]
# ## groupby()
# - Another very useful tool is [groupby()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html)
# - Say you want to know about the total number of people tested each month in Quebec
# - This is equivalent to reducing the number of observations to one per month and sum over the total number of tested

# %% [markdown]
# ### Problem
# - We need a variable that varies by month
# - For now we only have a variable that varies by day
# - You could you Pandas' powerful [datetime tools](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_datetime.html)
# - We will use the [split()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html) method instead.

# %%
# The date column is an object (string) type
print(qc['date'])
# use the split method on the string of a pandas series
# Out:
#        0   1     2
# 29    01  03  2020
# 33    03  03  2020
# 37    05  03  2020
# 41    06  03  2020
# 45    07  03  2020
# ...   ..  ..   ...
# 4682  13  01  2021
# 4697  14  01  2021
# 4712  15  01  2021
# 4727  16  01  2021
# 4742  17  01  2021
#
# [320 rows x 3 columns]

# %%
# unpack the values in 3 different columns using expand=True in split()
qc[['day','month','year']]=qc['date'].str.split(pat='-',expand=True)
# show tail()
qc.tail()
# Out:
#       prname        date  numtestedtoday day month  year
# 4682  Quebec  13-01-2021          8692.0  13    01  2021
# 4697  Quebec  14-01-2021          8955.0  14    01  2021
# 4712  Quebec  15-01-2021          8471.0  15    01  2021
# 4727  Quebec  16-01-2021          9590.0  16    01  2021
# 4742  Quebec  17-01-2021          9270.0  17    01  2021

# %% [markdown]
# We can now use groupby on the dataframe

# %%
# groupby year and month, and take the sum() of numtestedtoday
qc.groupby(['year','month'])['numtestedtoday'].sum().astype(int)
# Out:
# year  month
# 2020  03        67540
#       04       146507
#       05       222752
#       06       163515
#       07       219403
#       08       288470
#       09       416540
#       10       382212
#       11       279137
#       12       312265
# 2021  01       158193
# Name: numtestedtoday, dtype: int64

# %% [markdown]
# ## In class exercise
# - use groupby to find the maximum number of daily deaths each month in Ontario
# - First you'll need to get day, month and year in on dataframe
# - Hint: use the max() method

# %%
on[['day','month','year']]=on['date'].str.split(pat='-',expand=True)
on.groupby(['year','month'])['numdeathstoday'].max().astype(int)
# Out:
# year  month
# 2020  01        0
#       02        0
#       03       14
#       04       86
#       05       84
#       06       45
#       07       14
#       08        6
#       09        9
#       10       76
#       11       35
#       12       81
# 2021  01       89
# Name: numdeathstoday, dtype: int64

# %% [markdown]
# ### transform()
# - Say that I want to express the number of people tested each day as a percentage of the total number of people treated in the same month
# - First, we should find a way to keep the value for the within month sum
# - This is what calling [transform](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.transform.html) on a groupby() operation allows you to do

# %%
qc.groupby(['year','month'])['numtestedtoday'].transform(np.sum)
# Out:
# 29       67540.0
# 33       67540.0
# 37       67540.0
# 41       67540.0
# 45       67540.0
#           ...
# 4682    158193.0
# 4697    158193.0
# 4712    158193.0
# 4727    158193.0
# 4742    158193.0
# Name: numtestedtoday, Length: 320, dtype: float64

# %%
qc['monthly_tested']=qc.groupby(['year','month'])['numtestedtoday'].transform(np.sum)
qc.head()
# Out:
#     prname        date  numtestedtoday day month  year  monthly_tested
# 29  Quebec  01-03-2020             NaN  01    03  2020         67540.0
# 33  Quebec  03-03-2020             NaN  03    03  2020         67540.0
# 37  Quebec  05-03-2020             NaN  05    03  2020         67540.0
# 41  Quebec  06-03-2020             NaN  06    03  2020         67540.0
# 45  Quebec  07-03-2020             NaN  07    03  2020         67540.0

# %% [markdown]
# ## fillna()
# - Second we want to replace NaN values by zeros for tested
# - Warning: this is very rarely a good idea
# - But here we know that testing was not in place in early March and this is why the data is missing
# - We can fill the missing values with zeros using the [fillna()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.fillna.html) method

# %%
# fill missing values in qc['numtestedtoday'] with zeros
qc['numtestedtoday'].fillna(0)
# Out:
# 29         0.0
# 33         0.0
# 37         0.0
# 41         0.0
# 45         0.0
#          ...
# 4682    8692.0
# 4697    8955.0
# 4712    8471.0
# 4727    9590.0
# 4742    9270.0
# Name: numtestedtoday, Length: 320, dtype: float64

# %%
# Replace NaN by zeros for the numtestedtoday variable
qc['numtestedtoday']=qc['numtestedtoday'].fillna(0)
qc.head()
# Out:
#     prname        date  numtestedtoday day month  year  monthly_tested
# 29  Quebec  01-03-2020             0.0  01    03  2020         67540.0
# 33  Quebec  03-03-2020             0.0  03    03  2020         67540.0
# 37  Quebec  05-03-2020             0.0  05    03  2020         67540.0
# 41  Quebec  06-03-2020             0.0  06    03  2020         67540.0
# 45  Quebec  07-03-2020             0.0  07    03  2020         67540.0

# %% [markdown]
# We can now create our new variable

# %%
qc['share_tested']=qc['numtestedtoday']/qc['monthly_tested']*100
qc.tail()
# Out:
#       prname        date  numtestedtoday day month  year  monthly_tested  \
# 4682  Quebec  13-01-2021          8692.0  13    01  2021        158193.0
# 4697  Quebec  14-01-2021          8955.0  14    01  2021        158193.0
# 4712  Quebec  15-01-2021          8471.0  15    01  2021        158193.0
# 4727  Quebec  16-01-2021          9590.0  16    01  2021        158193.0
# 4742  Quebec  17-01-2021          9270.0  17    01  2021        158193.0
#
#       share_tested
# 4682      5.494554
# 4697      5.660807
# 4712      5.354851
# 4727      6.062215
# 4742      5.859931

# %% [markdown]
# ## In class exercise
# - What is the share of people tested in each province as percentage of the total number of people tested in Canada?
# 1. Create a dataframe named can, keeping the prname and numtestedtoday variables
# 2. Drop observations for 'Canada' and 'Repatriated travellers' in prname
# 3. Get the total number of people tested (hint: call sum on the column but do not use groupby)
# 4. Save the results in total_tested
# 5. Print out the total number of people tested in Canada
# 6. group the can dataframe by province and sum the total number of tested (suggestion: set as_index=False in groupby)
# 7. rename the variable _numtestedtoday_ to _totaltested_
# 8. Create a new colum, _total_, which contains the value in total_tested
# 9. Create a new column with the share for each province
# 10. show the head() of can for 13 observations

# %%
#1. Create a dataframe named can, keeping the prname and numtestedtoday variables
#2. Drop observations for 'Canada' and 'Repatriated travellers' in prname
can=df.loc[(df.prname!='Canada') &( df.prname!='Repatriated travellers'),['prname','numtestedtoday']]
#3. Get the total number of people tested (hint: call sum on the column but do not use groupby)
#4. Save the results in total_tested
total_tested=can['numtestedtoday'].sum()
#5. Print out the total number of people tested in Canada
print("{:,} tests were provided in Canada.".format(int(total_tested)))
#6. group the can dataframe by province and sum the total number of tested (suggestion: set as_index=False in groupby)
can=can.groupby(['prname'],as_index=False)['numtestedtoday'].sum()
#7. rename the variable numtestedtoday to totaltested
can.rename(columns={'numtestedtoday':'totaltested'},inplace=True)
# 8. Create a new colum, _total_, which contains the value in total_tested
can['total']=int(total_tested) #
#9. Create a new column with the share for each province
can['share_tested']=can['totaltested']/can['total']*100
can.head(n=13)
# Out:
# 16,557,007 tests were provided in Canada.
#                        prname  totaltested     total  share_tested
# 0                     Alberta    2979663.0  16557007     17.996387
# 1            British Columbia    1021911.0  16557007      6.172076
# 2                    Manitoba     436236.0  16557007      2.634752
# 3               New Brunswick     128255.0  16557007      0.774627
# 4   Newfoundland and Labrador      76391.0  16557007      0.461382
# 5       Northwest Territories       8323.0  16557007      0.050269
# 6                 Nova Scotia     195810.0  16557007      1.182641
# 7                     Nunavut       6558.0  16557007      0.039609
# 8                     Ontario    8633584.0  16557007     52.144594
# 9        Prince Edward Island      86220.0  16557007      0.520746
# 10                     Quebec    2656534.0  16557007     16.044772
# 11               Saskatchewan     321266.0  16557007      1.940363
# 12                      Yukon       6256.0  16557007      0.037785
